# %%
import pandas as pd
import numpy as np
import os 
os.chdir("D:\\Sales Logistic Project\\Decrypted\\")

# %% [raw]
# df= []
# for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
#     for filename in files:
#         df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
#         #print(len(df_tempa))
#         df_tempa.iloc[np.where(df_tempa.shape[1]==3)]
#         #if len(df_tempa.columns) == 3:
#         if 'Packet_Time' in df_tempa.columns:
#             #df_tempa['end_dt'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
#             df_tempa['Trip_Time'] = pd.to_datetime(df_tempa['Packet_Time'])
#             df_tempa['Path'] = str(path)
#             df_tempa['Trip_id'] = str(filename)
#                 #df_tempa['Trip_Id'] = filename
#             df.append(df_tempa)
#             dfframe = pd.concat(df, axis=0, ignore_index=True)

# %%
meta = pd.read_excel('D:\\Sales Logistic Project\\Metadata_v1.xltm',sheet_name='Sheet1')

# %%
meta
# Out:
#        SNO  TripIndex         File Description ( Path, Filename, Shape )  \
# 0        1          1  'D:\\Sales Logistic Project\\Decrypted\\25.10....
# 1        7          1  'D:\\Sales Logistic Project\\Decrypted\\25.10....
# 2       13          1  'D:\\Sales Logistic Project\\Decrypted\\25.10....
# 3       19          1  'D:\\Sales Logistic Project\\Decrypted\\25.10....
# 4       25          1  'D:\\Sales Logistic Project\\Decrypted\\25.10....
# ...    ...        ...                                                ...
# 1550  9301          1  'D:\\Sales Logistic Project\\Decrypted\\29.10....
# 1551  9307          1  'D:\\Sales Logistic Project\\Decrypted\\29.10....
# 1552  9313          1  'D:\\Sales Logistic Project\\Decrypted\\29.10....
# 1553  9319          1  'D:\\Sales Logistic Project\\Decrypted\\29.10....
# 1554  9325          1  'D:\\Sales Logistic Project\\Decrypted\\29.10....
#
#                               File  Row Count  Col Count File Format  \
# 0      'GJ12BV2880_16.10.2021.xls'       1450          2         F18
# 1      'GJ12BV6093_02.09.2021.xls'       1891          2         F18
# 2      'GJ12BV6093_02.10.2021.xls'       2019          2         F18
# 3      'GJ12BV7704_04.10.2021.xls'       1162          2         F18
# 4      'GJ12BV9360_01.10.2021.xls'       1163          2         F18
# ...                            ...        ...        ...         ...
# 1550  'NL01AC2463_11.09.2021.xlsx'        839          3         F10
# 1551  'NL01AC2465_08.09.2021.xlsx'       1134          3         F10
# 1552  'NL01AC2465_15.10.2021.xlsx'        843          3         F10
# 1553  'NL01AC2469_15.09.2021.xlsx'        566          3         F10
# 1554  'NL01AC2469_17.09.2021.xlsx'       2269          3         F10
#
#           col1       col2         col3  ...                 Val1  \
# 0     Lat,Lngt     Period            0  ...  13.003621,79.990784
# 1     Lat,Lngt     Period            0  ...  13.004339,79.990413
# 2     Lat,Lngt     Period            0  ...  13.004329,79.990362
# 3     Lat,Lngt     Period            0  ...   13.004265,79.99063
# 4     Lat,Lngt     Period            0  ...  12.995574,79.988806
# ...        ...        ...          ...  ...                  ...
#             df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
#             df_tempa.drop('Period', axis=1, inplace=True)
#             df_18.append(df_tempa)
#             dfframe = pd.concat(df_18, axis=0, ignore_index=True)
#         #if len(df_18) == 0:
#             #df_18 = df_tempa
#         #else:
#             #df_18.append(df_tempa)
#
#         #df_18 = pd.concat(df_tempa, axis=0, ignore_index=True)

# %%
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f18=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F18"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            df_tempa['Trip_id'] = str(filename)
            df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa.drop('Period', axis=1, inplace=True)
            df_f18.append(df_tempa)
            dfframe_format18 = pd.concat(df_f18, axis=0, ignore_index=True)
            dfframe_format18.Trip_id = dfframe_format18.Trip_id.str.replace('[xls]', '')

# %%
dfframe_format18.Trip_id.value_counts().sum()
# Out:
# 830962

# %%
dfframe_format18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830962 entries, 0 to 830961
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Lat,Lngt   830310 non-null  object
#  1   Trip_id    830962 non-null  object
#  2   Latitude   830310 non-null  float64
#  3   Longitude  830310 non-null  float64
#  4   GPS_dt_tm  830962 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 31.7+ MB

# %% [raw]
# dfframe_format18.isnull().sum()

# %%
#dfframe_format18.iloc[np.where(dfframe_test_a.isnull())]

# %%
dfframe_format18 = dfframe_format18.dropna(how='any',axis=0)

# %%
dfframe_format18.Trip_id.value_counts().count()
# Out:
# 672

# %%
dfframe_format18.isnull().sum()
# Out:
# Lat,Lngt     0
# Trip_id      0
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# dtype: int64

# %%
dfframe_format18.Trip_id.value_counts().sum()
# Out:
# 830310

# %%
dfframe_format18.head(2)
# Out:
#               Lat,Lngt                 Trip_id   Latitude  Longitude  \
# 0  13.003621,79.990784  GJ12BV2880_16.10.2021.  13.003621  79.990784
# 1  13.003621,79.990784  GJ12BV2880_16.10.2021.  13.003621  79.990784
#
#             GPS_dt_tm
# 0  2021-10 - 16 10:15
# 1  2021-10 - 16 10:20

# %%
dfframe_format18 = dfframe_format18[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format18
# Out:
#                        Trip_id             Lat,Lngt   Latitude  Longitude  \
# 0       GJ12BV2880_16.10.2021.  13.003621,79.990784  13.003621  79.990784
# 1       GJ12BV2880_16.10.2021.  13.003621,79.990784  13.003621  79.990784
# 2       GJ12BV2880_16.10.2021.  13.003621,79.990784  13.003621  79.990784
# 3       GJ12BV2880_16.10.2021.  13.003621,79.990784  13.003621  79.990784
# 4       GJ12BV2880_16.10.2021.  13.003621,79.990784  13.003621  79.990784
# ...                        ...                  ...        ...        ...
# 830956   NL01Q9795_02.09.2021.  22.588661,88.221088  22.588661  88.221088
# 830957   NL01Q9795_02.09.2021.   22.58866,88.221085  22.588660  88.221085
# 830958   NL01Q9795_02.09.2021.  22.588661,88.221088  22.588661  88.221088
# 830959   NL01Q9795_02.09.2021.  22.588661,88.221088  22.588661  88.221088
# 830960   NL01Q9795_02.09.2021.   22.58866,88.221085  22.588660  88.221085
#
#                  GPS_dt_tm
# 0       2021-10 - 16 10:15
# 1       2021-10 - 16 10:20
# 2       2021-10 - 16 10:25
# 3       2021-10 - 16 10:30
# 4       2021-10 - 16 10:35
# ...                    ...
# 830956  2021-09 - 07 23:35
# 830957  2021-09 - 07 23:40
# 830958  2021-09 - 07 23:45
# 830959  2021-09 - 07 23:55
# 830960  2021-09 - 07 23:57
#
# [830310 rows x 5 columns]

# %%
# format 17 
# most records have just the start time

# %%
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f17=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F17"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            df_tempa['Trip_id'] = str(filename)
            df_tempa['Period'] = df_tempa['Period'].replace(r'\n',' ', regex=True)
            df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace(r'\n',' ', regex=True)
            df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].str.replace(' ','')
            df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa.drop(df_tempa.loc[df_tempa['Lat,Lngt']=='0.02764413.026074'].index, inplace=True)
            df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            df_tempa.drop('Period', axis=1, inplace=True)
            df_f17.append(df_tempa)
            dfframe_format17 = pd.concat(df_f17, axis=0, ignore_index=True)
            dfframe_format17.Trip_id = dfframe_format17.Trip_id.str.replace('[.xls]', '')
            dfframe_format17.Trip_id = dfframe_format17.Trip_id.str.replace('[.xlsx]', '')
            #dfframe_format17.Trip_id = dfframe_format17.Trip_id.str.replace('[.xltm]', '')

# %%
#17/10 00:00

# %%
dfframe_format17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6758 entries, 0 to 6757
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Lat,Lngt   6749 non-null   object
#  1   Trip_id    6758 non-null   object
#  2   Latitude   6749 non-null   float64
#  3   Longitude  6749 non-null   float64
#  4   GPS_dt_tm  6758 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 264.1+ KB

# %%
dfframe_format17
# Out:
#                  Lat,Lngt              Trip_id   Latitude  Longitude  \
# 0     13.024057,80.027244  NL01AA3593_17102021  13.024057  80.027244
# 1     13.024057,80.027244  NL01AA3593_17102021  13.024057  80.027244
# 2     13.024057,80.027244  NL01AA3593_17102021  13.024057  80.027244
# 3     13.024057,80.027244  NL01AA3593_17102021  13.024057  80.027244
# 4     13.024057,80.027244  NL01AA3593_17102021  13.024057  80.027244
# ...                   ...                  ...        ...        ...
# 6753  21.134447,72.755644   NL01Q3114_04102021  21.134447  72.755644
# 6754  21.135269,72.754578   NL01Q3114_04102021  21.135269  72.754578
# 6755   21.135991,72.75408   NL01Q3114_04102021  21.135991  72.754080
# 6756  21.135416,72.754751   NL01Q3114_04102021  21.135416  72.754751
# 6757                  NaN   NL01Q3114_04102021        NaN        NaN
#
#                GPS_dt_tm
# 0    2021-10-17 00:00:00
# 1    2021-10-17 00:06:00
# 2    2021-10-17 00:12:00
# 3    2021-10-17 00:18:00
# 4    2021-10-17 00:24:00
# ...                  ...
# 6753 2021-10-07 14:36:00
# 6754 2021-10-07 14:42:00
# 6755 2021-10-07 14:48:00
# 6756 2021-10-07 14:54:00
# 6757 2021-10-04 00:00:00
#
# [6758 rows x 5 columns]

# %%
dfframe_format17.isnull().sum()
# Out:
# Lat,Lngt     9
# Trip_id      0
# Latitude     9
# Longitude    9
# GPS_dt_tm    0
# dtype: int64

# %%
#dfframe_format17.to_excel("17.xlsx")

# %%
dfframe_format17 = dfframe_format17.dropna(how='any',axis=0)

# %%
dfframe_format17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6749 entries, 0 to 6756
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Lat,Lngt   6749 non-null   object
#  1   Trip_id    6749 non-null   object
#  2   Latitude   6749 non-null   float64
#  3   Longitude  6749 non-null   float64
#  4   GPS_dt_tm  6749 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 316.4+ KB

# %%
dfframe_format17 = dfframe_format17[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format17.Trip_id.value_counts().count()
# Out:
# 10

# %%
dfframe_format17
# Out:
#                   Trip_id             Lat,Lngt   Latitude  Longitude  \
# 0     NL01AA3593_17102021  13.024057,80.027244  13.024057  80.027244
# 1     NL01AA3593_17102021  13.024057,80.027244  13.024057  80.027244
# 2     NL01AA3593_17102021  13.024057,80.027244  13.024057  80.027244
# 3     NL01AA3593_17102021  13.024057,80.027244  13.024057  80.027244
# 4     NL01AA3593_17102021  13.024057,80.027244  13.024057  80.027244
# ...                   ...                  ...        ...        ...
# 6752   NL01Q3114_04102021  21.124302,72.772507  21.124302  72.772507
# 6753   NL01Q3114_04102021  21.134447,72.755644  21.134447  72.755644
# 6754   NL01Q3114_04102021  21.135269,72.754578  21.135269  72.754578
# 6755   NL01Q3114_04102021   21.135991,72.75408  21.135991  72.754080
# 6756   NL01Q3114_04102021  21.135416,72.754751  21.135416  72.754751
#
#                GPS_dt_tm
# 0    2021-10-17 00:00:00
# 1    2021-10-17 00:06:00
# 2    2021-10-17 00:12:00
# 3    2021-10-17 00:18:00
# 4    2021-10-17 00:24:00
# ...                  ...
# 6752 2021-10-07 14:30:00
# 6753 2021-10-07 14:36:00
# 6754 2021-10-07 14:42:00
# 6755 2021-10-07 14:48:00
# 6756 2021-10-07 14:54:00
#
# [6749 rows x 5 columns]

# %%
## format 10 - 1489412
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f10=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F10"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            
            df_tempa['Trip_id'] = str(filename)
            #print(df_tempa['Trip_id'].value_counts())
            df_tempa['Packet Time'] = df_tempa['Packet Time'].replace('\n','', regex=True)
            df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
            df_tempa['Latitude'] = df_tempa['Latitude'].replace('\n','', regex=True)
            df_tempa['Longitude'] = df_tempa['Longitude'].replace('\n','', regex=True)
        
            #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa.drop('Period', axis=1, inplace=True)
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Packet Time'])
            df_f10.append(df_tempa)
            dfframe_format10 = pd.concat(df_f10, axis=0, ignore_index=True)
            #dfframe_format10.Trip_id = dfframe_format10.Trip_id.str.replace('[.xls]', '')
            #dfframe_format10.Trip_id = dfframe_format10.Trip_id.str.replace('[.xlsx]', '')

# %%
#dfframe_format10.to_csv("f10.csv")

# %%
#dfframe_format10 = dfframe_format10.dropna(how='any',axis=0)

# %%
dfframe_format10.shape
# Out:
# (1489412, 6)

# %%
1489412-1488853
# Out:
# 559

# %%
dfframe_format10.Trip_id.value_counts().count()
# Out:
# 637

# %%
dfframe_format10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1489412 entries, 0 to 1489411
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Latitude     1488853 non-null  float64
#  1   Longitude    1488853 non-null  float64
#  2   Packet Time  1488853 non-null  object
#  3   Trip_id      1489412 non-null  object
#  4   Lat,Lngt     1489412 non-null  object
#  5   GPS_dt_tm    1488853 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 68.2+ MB

# %%
dfframe_format10 = dfframe_format10.dropna(how='any',axis=0)

# %%
dfframe_format10.shape
# Out:
# (1488853, 6)

# %%
dfframe_format10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1488853 entries, 0 to 1489410
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Latitude     1488853 non-null  float64
#  1   Longitude    1488853 non-null  float64
#  2   Packet Time  1488853 non-null  object
#  3   Trip_id      1488853 non-null  object
#  4   Lat,Lngt     1488853 non-null  object
#  5   GPS_dt_tm    1488853 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 79.5+ MB

# %%
#dfframe_format10.to_csv("f10.csv")

# %%
dfframe_format10.Trip_id.nunique()
# Out:
# 637

# %%
## format 19
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f19=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F19"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
                df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
                df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
                df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
                df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            else:
                if('Date' in df_tempa):
                    df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                    df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            df_tempa['Path'] = str(path)
            df_f19.append(df_tempa)
            dfframe_format19 = pd.concat(df_f19, axis=0, ignore_index=True)
            #dfframe_format19.Trip_id = dfframe_format19.Trip_id.str.replace('[.xls]', '')
            #dfframe_format19.Trip_id = dfframe_format19.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format19.drop(dfframe_format19[['Date','Period']],axis=1,inplace=True)

# %%
dfframe_format19.Trip_id = dfframe_format19.Trip_id.str.replace('[.xls]', '')
dfframe_format19.Trip_id = dfframe_format19.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format19.Trip_id.value_counts()
# Out:
# NL01N7521_17102021     2685
# NL017527_04102021      2567
# NL01N0020_13082021     2542
# NL01AA1361_04102021    2478
# NL01AA1895_06082021    2442
#                        ...
# NL01AA1346_16102021     536
# NL01Q2734_01102021      531
# NL01AA7753_04102021     529
# NL01N9458_30092021      503
# NL01AC7384_11082021     123
# Name: Trip_id, Length: 133, dtype: int64

# %%
dfframe_format19.head(2)
# Out:
#               Lat,Lngt   Latitude  Longitude           GPS_dt_tm  \
# 0  13.004344,79.990042  13.004344  79.990042 2021-09-08 10:15:00
# 1  13.004344,79.990042  13.004344  79.990042 2021-09-08 10:20:00
#
#                LatLong             Trip_id  \
# 0  13.004344,79.990042  HR55U4599_08092021
# 1  13.004344,79.990042  HR55U4599_08092021
#
#                                                 Path GPS_dt_tm_new
# 0  D:\Sales Logistic Project\Decrypted\25.10.2021...           NaT
# 1  D:\Sales Logistic Project\Decrypted\25.10.2021...           NaT

# %%
dfframe_format19.isnull().sum()
# Out:
# Lat,Lngt              7
# Latitude              7
# Longitude             7
# GPS_dt_tm        170198
# LatLong               7
# Trip_id               0
# Path                  0
# GPS_dt_tm_new     10868
# dtype: int64

# %%
dfframe_format19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181066 entries, 0 to 181065
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Lat,Lngt       181059 non-null  object
#  1   Latitude       181059 non-null  float64
#  2   Longitude      181059 non-null  float64
#  3   GPS_dt_tm      10868 non-null   datetime64[ns]
#  4   LatLong        181059 non-null  object
#  5   Trip_id        181066 non-null  object
#  6   Path           181066 non-null  object
#  7   GPS_dt_tm_new  170198 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(4)
# memory usage: 11.1+ MB

# %%
#dfframe_format19.to_excel("19.xlsx")

# %%
dfframe_format19 = pd.read_excel("D:\\Sales Logistic Project\\F19.xltm")

# %%
dfframe_format19.isnull().sum()
# Out:
# Unnamed: 0    0
# Lat,Lngt      7
# Latitude      7
# Longitude     7
# Trip_id       0
# Path          0
# GPS_dt_tm     0
# dtype: int64

# %%
dfframe_format19.shape
# Out:
# (181066, 7)

# %%
#181066

# %%
dfframe_format19.isnull().sum()
# Out:
# Unnamed: 0    0
# Lat,Lngt      7
# Latitude      7
# Longitude     7
# Trip_id       0
# Path          0
# GPS_dt_tm     0
# dtype: int64

# %%
dfframe_format19 = dfframe_format19.dropna(how='any',axis=0)

# %%
dfframe_format19.shape
# Out:
# (181059, 7)

# %%
dfframe_format19.drop(dfframe_format19[['Unnamed: 0','Path']],axis=1,inplace=True)

# %%
dfframe_format19
# Out:
#                    Lat,Lngt   Latitude  Longitude             Trip_id  \
# 0       13.004344,79.990042  13.004344  79.990042  HR55U4599_08092021
# 1       13.004344,79.990042  13.004344  79.990042  HR55U4599_08092021
# 2       13.004344,79.990042  13.004344  79.990042  HR55U4599_08092021
# 3       13.004344,79.990042  13.004344  79.990042  HR55U4599_08092021
# 4       13.004344,79.990048  13.004344  79.990048  HR55U4599_08092021
# ...                     ...        ...        ...                 ...
# 181061    15.2959,76.912409  15.295900  76.912409  NL01Q6778_10082021
# 181062  15.267827,76.911796  15.267827  76.911796  NL01Q6778_10082021
# 181063  15.236758,76.908142  15.236758  76.908142  NL01Q6778_10082021
# 181064  15.200762,76.910693  15.200762  76.910693  NL01Q6778_10082021
# 181065  15.188828,76.911902  15.188828  76.911902  NL01Q6778_10082021
#
#                  GPS_dt_tm
# 0      2021-09-08 10:15:00
# 1      2021-09-08 10:20:00
# 2      2021-09-08 10:25:00
# 3      2021-09-08 10:30:00
# 4      2021-09-08 10:35:00
# ...                    ...
# 181061 2021-08-15 23:42:00
# 181062 2021-08-15 23:47:00
# 181063 2021-08-15 23:52:00
# 181064 2021-08-15 23:57:00
# 181065 2021-08-15 23:58:00
#
# [181059 rows x 5 columns]

# %%
dfframe_format19 = dfframe_format19[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format19
# Out:
#                    Trip_id             Lat,Lngt   Latitude  Longitude  \
# 0       HR55U4599_08092021  13.004344,79.990042  13.004344  79.990042
# 1       HR55U4599_08092021  13.004344,79.990042  13.004344  79.990042
# 2       HR55U4599_08092021  13.004344,79.990042  13.004344  79.990042
# 3       HR55U4599_08092021  13.004344,79.990042  13.004344  79.990042
# 4       HR55U4599_08092021  13.004344,79.990048  13.004344  79.990048
# ...                    ...                  ...        ...        ...
# 181061  NL01Q6778_10082021    15.2959,76.912409  15.295900  76.912409
# 181062  NL01Q6778_10082021  15.267827,76.911796  15.267827  76.911796
# 181063  NL01Q6778_10082021  15.236758,76.908142  15.236758  76.908142
# 181064  NL01Q6778_10082021  15.200762,76.910693  15.200762  76.910693
# 181065  NL01Q6778_10082021  15.188828,76.911902  15.188828  76.911902
#
#                  GPS_dt_tm
# 0      2021-09-08 10:15:00
# 1      2021-09-08 10:20:00
# 2      2021-09-08 10:25:00
# 3      2021-09-08 10:30:00
# 4      2021-09-08 10:35:00
# ...                    ...
# 181061 2021-08-15 23:42:00
# 181062 2021-08-15 23:47:00
# 181063 2021-08-15 23:52:00
# 181064 2021-08-15 23:57:00
# 181065 2021-08-15 23:58:00
#
# [181059 rows x 5 columns]

# %%
# format 9

# %%
## format 9
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f9=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F9"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
                #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
                #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
                #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f9.append(df_tempa)
            dfframe_format9 = pd.concat(df_f9, axis=0, ignore_index=True)
            #dfframe_format19.Trip_id = dfframe_format19.Trip_id.str.replace('[.xls]', '')
            #dfframe_format19.Trip_id = dfframe_format19.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68289 entries, 0 to 68288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Latitude   68289 non-null  float64
#  1   Longitude  68289 non-null  float64
#  2   GPS_dt_tm  68289 non-null  datetime64[ns]
#  3   Trip_id    68289 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 2.1+ MB

# %%
dfframe_format9.isnull().sum()
# Out:
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# Trip_id      0
# dtype: int64

# %%
dfframe_format9.Trip_id = dfframe_format9.Trip_id.str.replace('[.xls]', '')
dfframe_format9.Trip_id = dfframe_format9.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format9.Trip_id.value_counts().sum()
# Out:
# 68289

# %%
dfframe_format9['Lat,Lngt'] = dfframe_format9["Latitude"].astype(str) + dfframe_format9["Longitude"].astype(str)

# %%
dfframe_format9 = dfframe_format9[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format9
# Out:
#                    Trip_id                Lat,Lngt   Latitude  Longitude  \
# 0      NL01AB8077_21092021  13.0231170780.02675781  13.023117  80.026758
# 1      NL01AB8077_21092021  13.0231170780.02675781  13.023117  80.026758
# 2      NL01AB8077_21092021  13.0231170780.02675781  13.023117  80.026758
# 3      NL01AB8077_21092021  13.0231170780.02675781  13.023117  80.026758
# 4      NL01AB8077_21092021  13.0231170780.02675781  13.023117  80.026758
# ...                    ...                     ...        ...        ...
# 68284   NL01N3246_07092021  24.9922932983.85244954  24.992293  83.852450
# 68285   NL01N3246_07092021  25.0156941783.82591146  25.015694  83.825911
# 68286   NL01N3246_07092021  25.0403442483.80348307  25.040344  83.803483
# 68287   NL01N3246_07092021  25.0614807183.77119141  25.061481  83.771191
# 68288   NL01N3246_07092021   25.0825398883.7405599  25.082540  83.740560
#
#                 GPS_dt_tm
# 0     2021-09-17 00:00:00
# 1     2021-09-17 00:05:00
# 2     2021-09-17 00:10:00
# 3     2021-09-17 00:15:00
# 4     2021-09-17 00:20:00
# ...                   ...
# 68284 2021-09-14 17:40:00
# 68285 2021-09-14 17:45:00
# 68286 2021-09-14 17:50:00
# 68287 2021-09-14 17:55:00
# 68288 2021-09-14 18:00:00
#
# [68289 rows x 5 columns]

# %%
## format 7
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f7=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F7"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
                #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            
            #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f7.append(df_tempa)
            dfframe_format7 = pd.concat(df_f7, axis=0, ignore_index=True)
            dfframe_format7.Trip_id = dfframe_format7.Trip_id.str.replace('[.xls]', '')
            dfframe_format7.Trip_id = dfframe_format7.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25740 entries, 0 to 25739
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Lat,Lngt   25740 non-null  object
#  1   Date       25740 non-null  object
#  2   Time       25740 non-null  object
#  3   GPS_dt_tm  25740 non-null  datetime64[ns]
#  4   Latitude   25740 non-null  float64
#  5   Longitude  25740 non-null  float64
#  6   Trip_id    25740 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 1.4+ MB

# %%
#dfframe_format7.drop(dfframe_format7[['Date','Time']],axis=1,inplace=True)

# %%
dfframe_format7.head(3)
# Out:
#                 Lat,Lngt        Date      Time           GPS_dt_tm   Latitude  \
# 0  13.0132756,80.0024444  15-10-2021  00:00:27 2021-10-15 00:00:27  13.013276
# 1  13.0132756,80.0024444  15-10-2021  00:05:27 2021-10-15 00:05:27  13.013276
# 2  13.0132756,80.0024444  15-10-2021  00:10:27 2021-10-15 00:10:27  13.013276
#
#    Longitude              Trip_id
# 0  80.002444  NL01AB1201_15102021
# 1  80.002444  NL01AB1201_15102021
# 2  80.002444  NL01AB1201_15102021

# %%
dfframe_format7 = dfframe_format7[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format7.Trip_id.value_counts().count()
# Out:
# 25

# %%
dfframe_format7.isnull().sum()
# Out:
# Trip_id      0
# Lat,Lngt     0
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# dtype: int64

# %%
dfframe_format7.Trip_id.value_counts().sum()
# Out:
# 25740

# %%
## format 16
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f16=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F16"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            
            #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f16.append(df_tempa)
            dfframe_format16 = pd.concat(df_f16, axis=0, ignore_index=True)
            dfframe_format16.Trip_id = dfframe_format16.Trip_id.str.replace('[.xls]', '')
            dfframe_format16.Trip_id = dfframe_format16.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format16
# Out:
#                  Lat,Lngt                    Period   Latitude  Longitude  \
# 0     14.242812,79.887582  19/10 00:00 :19/10 00:06  14.242812  79.887582
# 1     14.226756,79.881298  19/10 00:06 :19/10 00:12  14.226756  79.881298
# 2     14.184558,79.869476  19/10 00:12 :19/10 00:18  14.184558  79.869476
# 3     14.157398,79.864978  19/10 00:18 :19/10 00:24  14.157398  79.864978
# 4     14.116826,79.874987  19/10 00:24 :19/10 00:30  14.116826  79.874987
# ...                   ...                       ...        ...        ...
# 2372   16.68855,74.291853  03/09 09:06 :03/09 09:12  16.688550  74.291853
# 2373  16.686973,74.292312  03/09 09:12 :03/09 09:18  16.686973  74.292312
# 2374  16.687845,74.292503  03/09 09:18 :03/09 09:24  16.687845  74.292503
# 2375  16.687845,74.292503  03/09 09:24 :03/09 09:28  16.687845  74.292503
# 2376                  NaN  01/09 00:00 :03/09 09:28        NaN        NaN
#
#                   Trip_id
# 0     NL01AA3592_19102021
# 1     NL01AA3592_19102021
# 2     NL01AA3592_19102021
# 3     NL01AA3592_19102021
# 4     NL01AA3592_19102021
# ...                   ...
# 2372   NL01Q2635_01092021
# 2373   NL01Q2635_01092021
# 2374   NL01Q2635_01092021
# 2375   NL01Q2635_01092021
# 2376   NL01Q2635_01092021
#
# [2377 rows x 5 columns]

# %%
dfframe_format16['GPS_dt_tm'] = dfframe_format16['Period'].map(lambda x:"2021"+"-"+str(x)[16:19]+"-"+str(x)[13:15]+" " +str(x)[19:25])

# %%
dfframe_format16['GPS_dt_tm'] = pd.to_datetime(dfframe_format16['GPS_dt_tm'])

# %%
dfframe_format16
# Out:
#                  Lat,Lngt                    Period   Latitude  Longitude  \
# 0     14.242812,79.887582  19/10 00:00 :19/10 00:06  14.242812  79.887582
# 1     14.226756,79.881298  19/10 00:06 :19/10 00:12  14.226756  79.881298
# 2     14.184558,79.869476  19/10 00:12 :19/10 00:18  14.184558  79.869476
# 3     14.157398,79.864978  19/10 00:18 :19/10 00:24  14.157398  79.864978
# 4     14.116826,79.874987  19/10 00:24 :19/10 00:30  14.116826  79.874987
# ...                   ...                       ...        ...        ...
# 2372   16.68855,74.291853  03/09 09:06 :03/09 09:12  16.688550  74.291853
# 2373  16.686973,74.292312  03/09 09:12 :03/09 09:18  16.686973  74.292312
# 2374  16.687845,74.292503  03/09 09:18 :03/09 09:24  16.687845  74.292503
# 2375  16.687845,74.292503  03/09 09:24 :03/09 09:28  16.687845  74.292503
# 2376                  NaN  01/09 00:00 :03/09 09:28        NaN        NaN
#
#                   Trip_id           GPS_dt_tm
# 0     NL01AA3592_19102021 2021-10-19 00:06:00
# 1     NL01AA3592_19102021 2021-10-19 00:12:00
# 2     NL01AA3592_19102021 2021-10-19 00:18:00
# 3     NL01AA3592_19102021 2021-10-19 00:24:00
# 4     NL01AA3592_19102021 2021-10-19 00:30:00
# ...                   ...                 ...
# 2372   NL01Q2635_01092021 2021-09-03 09:12:00
# 2373   NL01Q2635_01092021 2021-09-03 09:18:00
# 2374   NL01Q2635_01092021 2021-09-03 09:24:00
# 2375   NL01Q2635_01092021 2021-09-03 09:28:00
# 2376   NL01Q2635_01092021 2021-09-03 09:28:00
#
# [2377 rows x 6 columns]

# %%
dfframe_format16 = dfframe_format16[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format16.Trip_id.value_counts().count()
# Out:
# 4

# %%
dfframe_format16.Trip_id.value_counts().sum()
# Out:
# 2377

# %%
dfframe_format16.shape
# Out:
# (2377, 5)

# %%
dfframe_format9.isnull().sum()
# Out:
# Trip_id      0
# Lat,Lngt     0
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# dtype: int64

# %%
dfframe_format16
# Out:
#                   Trip_id             Lat,Lngt   Latitude  Longitude  \
# 0     NL01AA3592_19102021  14.242812,79.887582  14.242812  79.887582
# 1     NL01AA3592_19102021  14.226756,79.881298  14.226756  79.881298
# 2     NL01AA3592_19102021  14.184558,79.869476  14.184558  79.869476
# 3     NL01AA3592_19102021  14.157398,79.864978  14.157398  79.864978
# 4     NL01AA3592_19102021  14.116826,79.874987  14.116826  79.874987
# ...                   ...                  ...        ...        ...
# 2372   NL01Q2635_01092021   16.68855,74.291853  16.688550  74.291853
# 2373   NL01Q2635_01092021  16.686973,74.292312  16.686973  74.292312
# 2374   NL01Q2635_01092021  16.687845,74.292503  16.687845  74.292503
# 2375   NL01Q2635_01092021  16.687845,74.292503  16.687845  74.292503
# 2376   NL01Q2635_01092021                  NaN        NaN        NaN
#
#                GPS_dt_tm
# 0    2021-10-19 00:06:00
# 1    2021-10-19 00:12:00
# 2    2021-10-19 00:18:00
# 3    2021-10-19 00:24:00
# 4    2021-10-19 00:30:00
# ...                  ...
# 2372 2021-09-03 09:12:00
# 2373 2021-09-03 09:18:00
# 2374 2021-09-03 09:24:00
# 2375 2021-09-03 09:28:00
# 2376 2021-09-03 09:28:00
#
# [2377 rows x 5 columns]

# %%
dfframe_format16 = dfframe_format16.dropna(how='any',axis=0)

# %%
dfframe_format16.shape
# Out:
# (2373, 5)

# %%
## format 8
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f8=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F8"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f8.append(df_tempa)
            dfframe_format8 = pd.concat(df_f8, axis=0, ignore_index=True)
            dfframe_format8.Trip_id = dfframe_format8.Trip_id.str.replace('[.xls]', '')
            dfframe_format8.Trip_id = dfframe_format8.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format8['Trip_id'].value_counts().sum()
# Out:
# 5037

# %%
dfframe_format8.drop('Unnamed: 2',axis=1,inplace=True)

# %%
dfframe_format8
# Out:
#                  Lat,Lngt                     Period   Latitude  Longitude  \
# 0     13.024738,80.034861  01/09 00:00 : 01/09 00:05  13.024738  80.034861
# 1     13.024738,80.034861  01/09 00:05 : 01/09 00:10  13.024738  80.034861
# 2     13.024738,80.034861  01/09 00:10 : 01/09 00:15  13.024738  80.034861
# 3     13.024738,80.034861  01/09 00:15 : 01/09 00:20  13.024738  80.034861
# 4     13.024738,80.034861  01/09 00:20 : 01/09 00:25  13.024738  80.034861
# ...                   ...                        ...        ...        ...
# 5032  20.716156,77.177357  05/09 22:00 : 05/09 22:05  20.716156  77.177357
# 5033    20.71616,77.17735  05/09 22:05 : 05/09 22:10  20.716160  77.177350
# 5034  20.716164,77.177344  05/09 22:10 : 05/09 22:15  20.716164  77.177344
# 5035  20.716169,77.177338  05/09 22:15 : 05/09 22:19  20.716169  77.177338
# 5036                  NaN  01/09 00:00 : 05/09 22:19        NaN        NaN
#
#                GPS_dt_tm              Trip_id
# 0    2021-09-01 00:05:00  HR55AE0996_01092021
# 1    2021-09-01 00:10:00  HR55AE0996_01092021
# 2    2021-09-01 00:15:00  HR55AE0996_01092021
# 3    2021-09-01 00:20:00  HR55AE0996_01092021
# 4    2021-09-01 00:25:00  HR55AE0996_01092021
# ...                  ...                  ...
# 5032 2021-09-05 22:05:00   NL01Q0463_01092021
# 5033 2021-09-05 22:10:00   NL01Q0463_01092021
# 5034 2021-09-05 22:15:00   NL01Q0463_01092021
# 5035 2021-09-05 22:19:00   NL01Q0463_01092021
# 5036 2021-09-05 22:19:00   NL01Q0463_01092021
#
# [5037 rows x 6 columns]

# %%
dfframe_format8 = dfframe_format8.dropna(how='any',axis=0)

# %%
dfframe_format8 = dfframe_format8[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format8
# Out:
#                   Trip_id             Lat,Lngt   Latitude  Longitude  \
# 0     HR55AE0996_01092021  13.024738,80.034861  13.024738  80.034861
# 1     HR55AE0996_01092021  13.024738,80.034861  13.024738  80.034861
# 2     HR55AE0996_01092021  13.024738,80.034861  13.024738  80.034861
# 3     HR55AE0996_01092021  13.024738,80.034861  13.024738  80.034861
# 4     HR55AE0996_01092021  13.024738,80.034861  13.024738  80.034861
# ...                   ...                  ...        ...        ...
# 5031   NL01Q0463_01092021   20.716154,77.17735  20.716154  77.177350
# 5032   NL01Q0463_01092021  20.716156,77.177357  20.716156  77.177357
# 5033   NL01Q0463_01092021    20.71616,77.17735  20.716160  77.177350
# 5034   NL01Q0463_01092021  20.716164,77.177344  20.716164  77.177344
# 5035   NL01Q0463_01092021  20.716169,77.177338  20.716169  77.177338
#
#                GPS_dt_tm
# 0    2021-09-01 00:05:00
# 1    2021-09-01 00:10:00
# 2    2021-09-01 00:15:00
# 3    2021-09-01 00:20:00
# 4    2021-09-01 00:25:00
# ...                  ...
# 5031 2021-09-05 22:00:00
# 5032 2021-09-05 22:05:00
# 5033 2021-09-05 22:10:00
# 5034 2021-09-05 22:15:00
# 5035 2021-09-05 22:19:00
#
# [5033 rows x 5 columns]

# %%
dfframe_format8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5033 entries, 0 to 5035
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Trip_id    5033 non-null   object
#  1   Lat,Lngt   5033 non-null   object
#  2   Latitude   5033 non-null   float64
#  3   Longitude  5033 non-null   float64
#  4   GPS_dt_tm  5033 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 235.9+ KB

# %%
## format 4
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f4=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F4"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Time'])
            df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f4.append(df_tempa)
            dfframe_format4 = pd.concat(df_f4, axis=0, ignore_index=True)
            dfframe_format4.Trip_id = dfframe_format4.Trip_id.str.replace('[.xls]', '')
            dfframe_format4.Trip_id = dfframe_format4.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format4.Trip_id.value_counts().sum()
# Out:
# 3740

# %%
dfframe_format4 = dfframe_format4[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format4.isnull().sum()
# Out:
# Trip_id      0
# Lat,Lngt     0
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# dtype: int64

# %%
dfframe_format4
# Out:
#                  Trip_id            Lat,Lngt   Latitude  Longitude  \
# 0     NL01G7757_05102021   13.0254580.035118  13.025450  80.035118
# 1     NL01G7757_05102021  13.02538880.035141  13.025388  80.035141
# 2     NL01G7757_05102021   13.0254580.035118  13.025450  80.035118
# 3     NL01G7757_05102021   13.0254580.035118  13.025450  80.035118
# 4     NL01G7757_05102021   13.0254580.035118  13.025450  80.035118
# ...                  ...                 ...        ...        ...
# 3735  NL01G9427_10042021  13.02521580.035446  13.025215  80.035446
# 3736  NL01G9427_10042021  13.02521580.035446  13.025215  80.035446
# 3737  NL01G9427_10042021  13.02521580.035446  13.025215  80.035446
# 3738  NL01G9427_10042021  13.02521580.035446  13.025215  80.035446
# 3739  NL01G9427_10042021  13.02521580.035446  13.025215  80.035446
#
#                GPS_dt_tm
# 0    2021-05-10 00:00:00
# 1    2021-05-10 00:05:00
# 2    2021-05-10 00:10:00
# 3    2021-05-10 00:15:00
# 4    2021-05-10 00:20:00
# ...                  ...
# 3735 2021-06-10 23:30:00
# 3736 2021-06-10 23:35:00
# 3737 2021-06-10 23:40:00
# 3738 2021-06-10 23:45:00
# 3739 2021-06-10 23:50:00
#
# [3740 rows x 5 columns]

# %%
## format 13
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f13=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F13"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f13.append(df_tempa)
            dfframe_format13 = pd.concat(df_f13, axis=0, ignore_index=True)
            dfframe_format13.Trip_id = dfframe_format13.Trip_id.str.replace('[.xls]', '')
            dfframe_format13.Trip_id = dfframe_format13.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format13
# Out:
#        Latitude  Longitude           GPS_dt_tm            Lat,Lngt  \
# 0     13.025493  80.034393 2021-10-22 00:00:00  13.02549380.034393
# 1     13.025488  80.034477 2021-10-22 00:05:00  13.02548880.034477
# 2     13.025488  80.034477 2021-10-22 00:10:00  13.02548880.034477
# 3     13.025488  80.034477 2021-10-22 00:15:00  13.02548880.034477
# 4     13.025493  80.034508 2021-10-22 00:20:00  13.02549380.034508
# ...         ...        ...                 ...                 ...
# 3908  23.019222  72.261101 2021-10-25 23:30:00  23.01922272.261101
# 3909  23.019222  72.261101 2021-10-25 23:35:00  23.01922272.261101
# 3910  23.019222  72.261101 2021-10-25 23:40:00  23.01922272.261101
# 3911  23.019222  72.261101 2021-10-25 23:45:00  23.01922272.261101
# 3912  23.019222  72.261101 2021-10-25 23:50:00  23.01922272.261101
#
#                   Trip_id
# 0     NL01AB6060_22102021
# 1     NL01AB6060_22102021
# 2     NL01AB6060_22102021
# 3     NL01AB6060_22102021
# 4     NL01AB6060_22102021
# ...                   ...
# 3908   NL01K8784_19102021
# 3909   NL01K8784_19102021
# 3910   NL01K8784_19102021
# 3911   NL01K8784_19102021
# 3912   NL01K8784_19102021
#
# [3913 rows x 5 columns]

# %%
dfframe_format13.Trip_id.value_counts()
# Out:
# NL01K8784_19102021     2015
# NL01AB6060_22102021    1898
# Name: Trip_id, dtype: int64

# %%
dfframe_format13.isnull().sum()
# Out:
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# Lat,Lngt     0
# Trip_id      0
# dtype: int64

# %%
dfframe_format13 = dfframe_format13[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format13
# Out:
#                   Trip_id            Lat,Lngt   Latitude  Longitude  \
# 0     NL01AB6060_22102021  13.02549380.034393  13.025493  80.034393
# 1     NL01AB6060_22102021  13.02548880.034477  13.025488  80.034477
# 2     NL01AB6060_22102021  13.02548880.034477  13.025488  80.034477
# 3     NL01AB6060_22102021  13.02548880.034477  13.025488  80.034477
# 4     NL01AB6060_22102021  13.02549380.034508  13.025493  80.034508
# ...                   ...                 ...        ...        ...
# 3908   NL01K8784_19102021  23.01922272.261101  23.019222  72.261101
# 3909   NL01K8784_19102021  23.01922272.261101  23.019222  72.261101
# 3910   NL01K8784_19102021  23.01922272.261101  23.019222  72.261101
# 3911   NL01K8784_19102021  23.01922272.261101  23.019222  72.261101
# 3912   NL01K8784_19102021  23.01922272.261101  23.019222  72.261101
#
#                GPS_dt_tm
# 0    2021-10-22 00:00:00
# 1    2021-10-22 00:05:00
# 2    2021-10-22 00:10:00
# 3    2021-10-22 00:15:00
# 4    2021-10-22 00:20:00
# ...                  ...
# 3908 2021-10-25 23:30:00
# 3909 2021-10-25 23:35:00
# 3910 2021-10-25 23:40:00
# 3911 2021-10-25 23:45:00
# 3912 2021-10-25 23:50:00
#
# [3913 rows x 5 columns]

# %%
## format 2
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f2=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F2"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f2.append(df_tempa)
            dfframe_format2 = pd.concat(df_f2, axis=0, ignore_index=True)
            dfframe_format2.Trip_id = dfframe_format2.Trip_id.str.replace('[.xls]', '')
            dfframe_format2.Trip_id = dfframe_format2.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format2.drop(dfframe_format2[['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5']],axis=1,inplace=True)

# %%
dfframe_format2.shape
# Out:
# (2654, 6)

# %%
dfframe_format2.isnull().sum()
# Out:
# Lat,Lngt     2
# Period       0
# Latitude     2
# Longitude    2
# GPS_dt_tm    0
# Trip_id      0
# dtype: int64

# %%
dfframe_format2 = dfframe_format2.dropna(how='any',axis=0)

# %%
dfframe_format2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2652 entries, 0 to 2652
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Lat,Lngt   2652 non-null   object
#  1   Period     2652 non-null   object
#  2   Latitude   2652 non-null   float64
#  3   Longitude  2652 non-null   float64
#  4   GPS_dt_tm  2652 non-null   datetime64[ns]
#  5   Trip_id    2652 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 145.0+ KB

# %%
dfframe_format2 = dfframe_format2[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format2
# Out:
#                  Trip_id             Lat,Lngt   Latitude  Longitude  \
# 0     HR55S4482_07092021   12.985476,80.00984  12.985476  80.009840
# 1     HR55S4482_07092021   12.985476,80.00984  12.985476  80.009840
# 2     HR55S4482_07092021   12.985476,80.00984  12.985476  80.009840
# 3     HR55S4482_07092021   12.985476,80.00984  12.985476  80.009840
# 4     HR55S4482_07092021   12.985476,80.00984  12.985476  80.009840
# ...                  ...                  ...        ...        ...
# 2648   KA429932_29092021  12.919132,79.340781  12.919132  79.340781
# 2649   KA429932_29092021  12.912896,79.375315  12.912896  79.375315
# 2650   KA429932_29092021  12.909772,79.403622  12.909772  79.403622
# 2651   KA429932_29092021  12.901708,79.432851  12.901708  79.432851
# 2652   KA429932_29092021   12.900599,79.45945  12.900599  79.459450
#
#                GPS_dt_tm
# 0    2021-09-07 00:05:00
# 1    2021-09-07 00:10:00
# 2    2021-09-07 00:15:00
# 3    2021-09-07 00:20:00
# 4    2021-09-07 00:25:00
# ...                  ...
# 2648 2021-10-01 10:40:00
# 2649 2021-10-01 10:45:00
# 2650 2021-10-01 10:50:00
# 2651 2021-10-01 10:55:00
# 2652 2021-10-01 10:58:00
#
# [2652 rows x 5 columns]

# %%
## format 6
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f6=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F6"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            ##df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f6.append(df_tempa)
            dfframe_format6 = pd.concat(df_f6, axis=0, ignore_index=True)
            dfframe_format6.Trip_id = dfframe_format6.Trip_id.str.replace('[.xls]', '')
            dfframe_format6.Trip_id = dfframe_format6.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format6
# Out:
#        Vehicle               Lat,Lngt        Date      Time  \
# 0    NL01K8951  12.9944278,80.0126844  04-09-2021  01:03:25
# 1    NL01K8951  12.9944278,80.0126844  04-09-2021  01:08:25
# 2    NL01K8951  12.9944278,80.0126844  04-09-2021  01:41:33
# 3    NL01K8951    12.9993233,80.01368  04-09-2021  01:46:39
# 4    NL01K8951  13.0039756,79.9936978  04-09-2021  01:51:39
# ..         ...                    ...         ...       ...
# 631  NL01K8951    22.47904,88.0699733  09-09-2021  15:02:58
# 632  NL01K8951    22.47904,88.0699733  09-09-2021  16:07:12
# 633  NL01K8951    22.47904,88.0699733  09-09-2021  20:22:53
# 634  NL01K8951    22.47904,88.0699733  09-09-2021  21:29:49
# 635  NL01K8951  22.4792689,88.0686222  09-09-2021  22:34:59
#
#               GPS_dt_tm   Latitude  Longitude             Trip_id
# 0   2021-04-09 01:03:25  12.994428  80.012684  NL01K8951_04092021
# 1   2021-04-09 01:08:25  12.994428  80.012684  NL01K8951_04092021
# 2   2021-04-09 01:41:33  12.994428  80.012684  NL01K8951_04092021
# 3   2021-04-09 01:46:39  12.999323  80.013680  NL01K8951_04092021
# 4   2021-04-09 01:51:39  13.003976  79.993698  NL01K8951_04092021
# ..                  ...        ...        ...                 ...
# 631 2021-09-09 15:02:58  22.479040  88.069973  NL01K8951_04092021
# 632 2021-09-09 16:07:12  22.479040  88.069973  NL01K8951_04092021
# 633 2021-09-09 20:22:53  22.479040  88.069973  NL01K8951_04092021
# 634 2021-09-09 21:29:49  22.479040  88.069973  NL01K8951_04092021
# 635 2021-09-09 22:34:59  22.479269  88.068622  NL01K8951_04092021
#
# [636 rows x 8 columns]

# %%
dfframe_format6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Vehicle    636 non-null    object
#  1   Lat,Lngt   636 non-null    object
#  2   Date       636 non-null    object
#  3   Time       636 non-null    object
#  4   GPS_dt_tm  636 non-null    datetime64[ns]
#  5   Latitude   636 non-null    float64
#  6   Longitude  636 non-null    float64
#  7   Trip_id    636 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 39.9+ KB

# %%
dfframe_format6.drop(dfframe_format6[['Vehicle','Date','Time']], axis=1, inplace=True)
#dfframe_format2.drop(dfframe_format2[['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5']],axis=1,inplace=True)

# %%
dfframe_format6 = dfframe_format6[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format6
# Out:
#                 Trip_id               Lat,Lngt   Latitude  Longitude  \
# 0    NL01K8951_04092021  12.9944278,80.0126844  12.994428  80.012684
# 1    NL01K8951_04092021  12.9944278,80.0126844  12.994428  80.012684
# 2    NL01K8951_04092021  12.9944278,80.0126844  12.994428  80.012684
# 3    NL01K8951_04092021    12.9993233,80.01368  12.999323  80.013680
# 4    NL01K8951_04092021  13.0039756,79.9936978  13.003976  79.993698
# ..                  ...                    ...        ...        ...
# 631  NL01K8951_04092021    22.47904,88.0699733  22.479040  88.069973
# 632  NL01K8951_04092021    22.47904,88.0699733  22.479040  88.069973
# 633  NL01K8951_04092021    22.47904,88.0699733  22.479040  88.069973
# 634  NL01K8951_04092021    22.47904,88.0699733  22.479040  88.069973
# 635  NL01K8951_04092021  22.4792689,88.0686222  22.479269  88.068622
#
#               GPS_dt_tm
# 0   2021-04-09 01:03:25
# 1   2021-04-09 01:08:25
# 2   2021-04-09 01:41:33
# 3   2021-04-09 01:46:39
# 4   2021-04-09 01:51:39
# ..                  ...
# 631 2021-09-09 15:02:58
# 632 2021-09-09 16:07:12
# 633 2021-09-09 20:22:53
# 634 2021-09-09 21:29:49
# 635 2021-09-09 22:34:59
#
# [636 rows x 5 columns]

# %%
dfframe_format6.isnull().sum()
# Out:
# Trip_id      0
# Lat,Lngt     0
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# dtype: int64

# %%
dfframe_format6.Trip_id.value_counts().sum()
# Out:
# 636

# %%
## format 14
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f14=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F14"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            df_tempa = df_tempa[1:]
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            ##df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f14.append(df_tempa)
            dfframe_format14 = pd.concat(df_f14, axis=0, ignore_index=True)
            dfframe_format14.Trip_id = dfframe_format14.Trip_id.str.replace('[.xls]', '')
            dfframe_format14.Trip_id = dfframe_format14.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format14
# Out:
#         Latitude    Longitude           GPS_dt_tm                Lat,Lngt  \
# 0    13.02285258  80.02658691 2021-09-24 06:23:00  13.0228525880.02658691
# 1    13.02314453  80.02679850 2021-09-24 08:17:00  13.0231445380.02679850
# 2    13.02311808  80.02672526 2021-09-24 08:35:00  13.0231180880.02672526
# 3    13.02303263  80.02679850 2021-09-24 11:57:00  13.0230326380.02679850
# 4    13.02312215  80.02670898 2021-09-24 12:18:00  13.0231221580.02670898
# ..           ...          ...                 ...                     ...
# 815  24.33034261  85.37680664 2021-10-01 18:34:00  24.3303426185.37680664
# 816  24.33858032  85.36283366 2021-10-01 18:38:00  24.3385803285.36283366
# 817  24.34885050  85.34134928 2021-10-01 18:44:00  24.3488505085.34134928
# 818  24.35744222  85.32044271 2021-10-01 18:49:00  24.3574422285.32044271
# 819  24.36765747  85.29450684 2021-10-01 18:54:00  24.3676574785.29450684
#
#                  Trip_id
# 0    NL01AD9973_24092021
# 1    NL01AD9973_24092021
# 2    NL01AD9973_24092021
# 3    NL01AD9973_24092021
# 4    NL01AD9973_24092021
# ..                   ...
# 815  NL01AD9973_24092021
# 816  NL01AD9973_24092021
# 817  NL01AD9973_24092021
# 818  NL01AD9973_24092021
# 819  NL01AD9973_24092021
#
# [820 rows x 5 columns]

# %%
dfframe_format14.isnull().sum()
# Out:
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# Lat,Lngt     0
# Trip_id      0
# dtype: int64

# %%
dfframe_format14 = dfframe_format14[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
## format 5
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f5=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F5"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa = df_tempa[1:]
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            df_tempa.columns = ['License_Number','Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            ##df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f5.append(df_tempa)
            dfframe_format5 = pd.concat(df_f5, axis=0, ignore_index=True)
            dfframe_format5.Trip_id = dfframe_format5.Trip_id.str.replace('[.xls]', '')
            dfframe_format5.Trip_id = dfframe_format5.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format5
# Out:
#     License_Number   Latitude  Longitude           GPS_dt_tm  \
# 0        NL01G7717  13.025347  80.035110 2021-10-23 00:00:00
# 1        NL01G7717  13.025368  80.035034 2021-10-23 00:05:00
# 2        NL01G7717  13.025368  80.035034 2021-10-23 00:10:00
# 3        NL01G7717  13.025343  80.034996 2021-10-23 00:15:00
# 4        NL01G7717  13.025343  80.034996 2021-10-23 00:20:00
# ..             ...        ...        ...                 ...
# 858      NL01G7717   8.674968  77.755463 2021-10-25 23:30:00
# 859      NL01G7717   8.699787  77.766144 2021-10-25 23:35:00
# 860      NL01G7717   8.728313  77.761101 2021-10-25 23:40:00
# 861      NL01G7717   8.728313  77.761101 2021-10-25 23:45:00
# 862      NL01G7717   8.728313  77.761101 2021-10-25 23:50:00
#
#                Lat,Lngt             Trip_id
# 0     13.02534780.03511  NL01G7717_23102021
# 1    13.02536880.035034  NL01G7717_23102021
# 2    13.02536880.035034  NL01G7717_23102021
# 3    13.02534380.034996  NL01G7717_23102021
# 4    13.02534380.034996  NL01G7717_23102021
# ..                  ...                 ...
# 858   8.67496877.755463  NL01G7717_23102021
# 859   8.69978777.766144  NL01G7717_23102021
# 860   8.72831377.761101  NL01G7717_23102021
# 861   8.72831377.761101  NL01G7717_23102021
# 862   8.72831377.761101  NL01G7717_23102021
#
# [863 rows x 6 columns]

# %%
dfframe_format5.drop(['License_Number'],axis=1,inplace=True)

# %%
dfframe_format5 = dfframe_format5[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Trip_id    863 non-null    object
#  1   Lat,Lngt   863 non-null    object
#  2   Latitude   863 non-null    float64
#  3   Longitude  863 non-null    float64
#  4   GPS_dt_tm  863 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 33.8+ KB

# %%
dfframe_format5.isnull().sum()
# Out:
# Trip_id      0
# Lat,Lngt     0
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# dtype: int64

# %% [raw]
# ## format 3
# #print(x["'NL01AC2907_02.09.2021.xlsx'"])
# df_f1=[]
# for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
#     for filename in files:
#         fmt_typ = file_frmts[("'" + filename + "'")]
#         if (fmt_typ == "F1"):
#             df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
#             #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
#             #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
#             #if 'Period' in df_tempa:
#             #print(df_tempa['Trip_id'].value_counts())
#                 #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
#             df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
#             df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
#             df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
#             df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
#             df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
#             #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
#             df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
#             df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Packet Time'])
#             #df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
#             #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
#             #else:
#                 #if('Date' in df_tempa):
#                     #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
#                    #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
#                     #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
#                     #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
#                     #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
#
#             df_tempa['Trip_id'] = str(filename)
#             #df_tempa['Path'] = str(path)
#             df_f1.append(df_tempa)
#             dfframe_format1 = pd.concat(df_f1, axis=0, ignore_index=True)
#             dfframe_format1.Trip_id = dfframe_format1.Trip_id.str.replace('[.xls]', '')
#             dfframe_format1.Trip_id = dfframe_format1.Trip_id.str.replace('[.xlsx]', '')

# %%
## format 1
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f1=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F1"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa = df_tempa[1:]
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['License_Number','Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            ##df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['GPS_dt_tm'])
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)

# %%
df_f1.append(df_tempa)
dfframe_format1 = pd.concat(df_f1, axis=0, ignore_index=True)
dfframe_format1.Trip_id = dfframe_format1.Trip_id.str.replace('[.xls]', '')
dfframe_format1.Trip_id = dfframe_format1.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License_Number  863 non-null    object
#  1   Latitude        863 non-null    float64
#  2   Longitude       863 non-null    float64
#  3   GPS_dt_tm       863 non-null    datetime64[ns]
#  4   Lat,Lngt        863 non-null    object
#  5   Trip_id         863 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 40.6+ KB

# %%
dfframe_format1 = dfframe_format1.dropna(how='any',axis=0)

# %%
dfframe_format1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 863 entries, 0 to 862
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   License_Number  863 non-null    object
#  1   Latitude        863 non-null    float64
#  2   Longitude       863 non-null    float64
#  3   GPS_dt_tm       863 non-null    datetime64[ns]
#  4   Lat,Lngt        863 non-null    object
#  5   Trip_id         863 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 47.2+ KB

# %%
dfframe_format1.Trip_id.value_counts()
# Out:
# NL01G7717_23102021    863
# Name: Trip_id, dtype: int64

# %%
dfframe_format1 = dfframe_format1[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 863 entries, 0 to 862
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Trip_id    863 non-null    object
#  1   Lat,Lngt   863 non-null    object
#  2   Latitude   863 non-null    float64
#  3   Longitude  863 non-null    float64
#  4   GPS_dt_tm  863 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 40.5+ KB

# %%
dfframe_format1
# Out:
#                 Trip_id            Lat,Lngt   Latitude  Longitude  \
# 0    NL01G7717_23102021   13.02534780.03511  13.025347  80.035110
# 1    NL01G7717_23102021  13.02536880.035034  13.025368  80.035034
# 2    NL01G7717_23102021  13.02536880.035034  13.025368  80.035034
# 3    NL01G7717_23102021  13.02534380.034996  13.025343  80.034996
# 4    NL01G7717_23102021  13.02534380.034996  13.025343  80.034996
# ..                  ...                 ...        ...        ...
# 858  NL01G7717_23102021   8.67496877.755463   8.674968  77.755463
# 859  NL01G7717_23102021   8.69978777.766144   8.699787  77.766144
# 860  NL01G7717_23102021   8.72831377.761101   8.728313  77.761101
# 861  NL01G7717_23102021   8.72831377.761101   8.728313  77.761101
# 862  NL01G7717_23102021   8.72831377.761101   8.728313  77.761101
#
#               GPS_dt_tm
# 0   2021-10-23 00:00:00
# 1   2021-10-23 00:05:00
# 2   2021-10-23 00:10:00
# 3   2021-10-23 00:15:00
# 4   2021-10-23 00:20:00
# ..                  ...
# 858 2021-10-25 23:30:00
# 859 2021-10-25 23:35:00
# 860 2021-10-25 23:40:00
# 861 2021-10-25 23:45:00
# 862 2021-10-25 23:50:00
#
# [863 rows x 5 columns]

# %%
## format 3
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f3=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F3"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Packet Time'])
            df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f3.append(df_tempa)
            dfframe_format3 = pd.concat(df_f3, axis=0, ignore_index=True)
            dfframe_format3.Trip_id = dfframe_format3.Trip_id.str.replace('[.xls]', '')
            dfframe_format3.Trip_id = dfframe_format3.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format3.Trip_id.value_counts()
# Out:
# HR46E1707_24092021    25332
# Name: Trip_id, dtype: int64

# %%
dfframe_format3.isnull().sum()
# Out:
# Unnamed: 0     25332
# Truck No           1
# Latitude           1
# Longitude          1
# Packet Time        1
# GPS_dt_tm          1
# Lat,Lngt           0
# Trip_id            0
# dtype: int64

# %%
dfframe_format3.drop(dfframe_format3[['Unnamed: 0','Truck No']],axis=1,inplace=True)

# %%
dfframe_format3.isnull().sum()
# Out:
# Latitude       1
# Longitude      1
# Packet Time    1
# GPS_dt_tm      1
# Lat,Lngt       0
# Trip_id        0
# dtype: int64

# %%
dfframe_format3 = dfframe_format3.dropna(how='any',axis=0)

# %%
dfframe_format3.shape
# Out:
# (25331, 6)

# %%
dfframe_format3
# Out:
#         Latitude  Longitude        Packet Time           GPS_dt_tm  \
# 0      13.024173  80.027069  24-Sep-2021 02:05 2021-09-24 02:05:00
# 1      13.024173  80.027046  24-Sep-2021 02:05 2021-09-24 02:05:00
# 2      13.024349  80.027046  24-Sep-2021 14:07 2021-09-24 14:07:00
# 3      13.024349  80.027046  24-Sep-2021 14:07 2021-09-24 14:07:00
# 4      13.024341  80.027046  24-Sep-2021 14:08 2021-09-24 14:08:00
# ...          ...        ...                ...                 ...
# 25326  28.375179  76.951096  03-Oct-2021 23:57 2021-10-03 23:57:00
# 25327  28.375179  76.951096  03-Oct-2021 23:58 2021-10-03 23:58:00
# 25328  28.375179  76.951096  03-Oct-2021 23:58 2021-10-03 23:58:00
# 25329  28.375179  76.951096  03-Oct-2021 23:59 2021-10-03 23:59:00
# 25330  28.375179  76.951096  03-Oct-2021 23:59 2021-10-03 23:59:00
#
#                  Lat,Lngt             Trip_id
# 0      13.02417380.027069  HR46E1707_24092021
# 1      13.02417380.027046  HR46E1707_24092021
# 2      13.02434980.027046  HR46E1707_24092021
# 3      13.02434980.027046  HR46E1707_24092021
# 4      13.02434180.027046  HR46E1707_24092021
# ...                   ...                 ...
# 25326  28.37517976.951096  HR46E1707_24092021
# 25327  28.37517976.951096  HR46E1707_24092021
# 25328  28.37517976.951096  HR46E1707_24092021
# 25329  28.37517976.951096  HR46E1707_24092021
# 25330  28.37517976.951096  HR46E1707_24092021
#
# [25331 rows x 6 columns]

# %%
dfframe_format3 = dfframe_format3[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
## format 11
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f11=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F11"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Packet Time'])
            df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f11.append(df_tempa)
            dfframe_format11 = pd.concat(df_f11, axis=0, ignore_index=True)
            dfframe_format11.Trip_id = dfframe_format11.Trip_id.str.replace('[.xls]', '')
            dfframe_format11.Trip_id = dfframe_format11.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format11
# Out:
#       Latitude  Longitude        Packet Time           GPS_dt_tm  \
# 0    12.994770  80.012856  20-Aug-2021 00:05 2021-08-20 00:05:00
# 1    12.994770  80.012856  20-Aug-2021 00:10 2021-08-20 00:10:00
# 2    12.994770  80.012856  20-Aug-2021 00:15 2021-08-20 00:15:00
# 3    12.994770  80.012856  20-Aug-2021 00:20 2021-08-20 00:20:00
# 4    12.994770  80.012856  20-Aug-2021 00:25 2021-08-20 00:25:00
# ..         ...        ...                ...                 ...
# 274  12.642815  78.056099  20-Aug-2021 23:48 2021-08-20 23:48:00
# 275  12.642815  78.056099  20-Aug-2021 23:53 2021-08-20 23:53:00
# 276  12.642815  78.056099  20-Aug-2021 23:58 2021-08-20 23:58:00
# 277  12.642815  78.056099  20-Aug-2021 23:59 2021-08-20 23:59:00
# 278        NaN        NaN                NaN                 NaT
#
#                Lat,Lngt             Trip_id
# 0     12.9947780.012856  HR38W4395_20082021
# 1     12.9947780.012856  HR38W4395_20082021
# 2     12.9947780.012856  HR38W4395_20082021
# 3     12.9947780.012856  HR38W4395_20082021
# 4     12.9947780.012856  HR38W4395_20082021
# ..                  ...                 ...
# 274  12.64281578.056099  HR38W4395_20082021
# 275  12.64281578.056099  HR38W4395_20082021
# 276  12.64281578.056099  HR38W4395_20082021
# 277  12.64281578.056099  HR38W4395_20082021
# 278              nannan  HR38W4395_20082021
#
# [279 rows x 6 columns]

# %%
dfframe_format11 = dfframe_format11[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Trip_id    279 non-null    object
#  1   Lat,Lngt   279 non-null    object
#  2   Latitude   278 non-null    float64
#  3   Longitude  278 non-null    float64
#  4   GPS_dt_tm  278 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 11.0+ KB

# %%
dfframe_format11.Trip_id.value_counts()
# Out:
# HR38W4395_20082021    279
# Name: Trip_id, dtype: int64

# %%
dfframe_format11 = dfframe_format11.dropna(how='any',axis=0)

# %%
dfframe_format11.shape
# Out:
# (278, 5)

# %%
## format 12
#print(x["'NL01AC2907_02.09.2021.xlsx'"])
df_f12=[]
for path, subdirs, files in os.walk("D:\\Sales Logistic Project\\Decrypted\\"):
    for filename in files:
        fmt_typ = file_frmts[("'" + filename + "'")]   
        if (fmt_typ == "F12"):
            df_tempa=pd.read_excel(os.path.join(path, filename),index_col=None)
            #df_tempa['GPS_dt_time'] = pd.to_datetime(df_tempa['Date'] + ' ' + df_tempa['Time'])
            #df_tempa.columns = ['Latitude', 'Longitude', 'GPS_dt_tm']
            #if 'Period' in df_tempa:
            #print(df_tempa['Trip_id'].value_counts())
                #df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Date'])
            #df_tempa['Period'] = df_tempa['Period'].replace('\n','', regex=True)
            #df_tempa['Lat,Lngt'] = df_tempa['Lat,Lngt'].replace('\n','', regex=True)
            #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
            #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
            #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'][0:6].map(lambda x:"2021"+"-"+str(x)[3:5]+"-"+str(x)[0:2]+" "+str(x)[6:11])
            #df_tempa['GPS_dt_tm'] = df_tempa['Period'].map(lambda x:"2021"+"-"+str(x)[17:20]+"-"+str(x)[13:16]+" "+str(x)[20:25])
            df_tempa['GPS_dt_tm'] = pd.to_datetime(df_tempa['Time'])
            df_tempa['Lat,Lngt'] = df_tempa["Latitude"].astype(str) + df_tempa["Longitude"].astype(str)
            #df_tempa['LatLong'] = df_tempa['Lat,Lngt']
            #else:
                #if('Date' in df_tempa):
                    #df_tempa['GPS_dt_tm_new'] = pd.to_datetime(df_tempa['Date'])
                   #df_tempa['Lat,Lngt'] = df_tempa['LatLong']
                    #df_tempa[['Latitude', 'Longitude']] = df_tempa['Lat,Lngt'].str.split(',', 1, expand=True)
                    #df_tempa['Latitude'] = df_tempa['Latitude'].astype(float)
                    #df_tempa['Longitude'] = df_tempa['Longitude'].astype(float)
                
            df_tempa['Trip_id'] = str(filename)
            #df_tempa['Path'] = str(path)
            df_f12.append(df_tempa)
            dfframe_format12 = pd.concat(df_f12, axis=0, ignore_index=True)
            dfframe_format12.Trip_id = dfframe_format12.Trip_id.str.replace('[.xls]', '')
            dfframe_format12.Trip_id = dfframe_format12.Trip_id.str.replace('[.xlsx]', '')

# %%
dfframe_format12
# Out:
#         Latitude  Longitude               Time           GPS_dt_tm  \
# 0      13.025482  80.034416  04/10/21 12:00 AM 2021-04-10 00:00:00
# 1      13.025388  80.034363  04/10/21 12:05 AM 2021-04-10 00:05:00
# 2      13.026557  80.034843  04/10/21 12:10 AM 2021-04-10 00:10:00
# 3      13.020853  80.014626  04/10/21 12:15 AM 2021-04-10 00:15:00
# 4      13.003177  79.996902  04/10/21 12:20 AM 2021-04-10 00:20:00
# ...          ...        ...                ...                 ...
# 16398  18.503422  73.927742  16/10/21 11:30 PM 2021-10-16 23:30:00
# 16399  18.499826  73.946236  16/10/21 11:35 PM 2021-10-16 23:35:00
# 16400  18.497791  73.961311  16/10/21 11:40 PM 2021-10-16 23:40:00
# 16401  18.497791  73.961311  16/10/21 11:45 PM 2021-10-16 23:45:00
# 16402  18.497791  73.961311  16/10/21 11:50 PM 2021-10-16 23:50:00
#
#                  Lat,Lngt              Trip_id
# 0      13.02548280.034416  NL01AB6068_04102021
# 1      13.02538880.034363  NL01AB6068_04102021
# 2      13.02655780.034843  NL01AB6068_04102021
# 3      13.02085380.014626  NL01AB6068_04102021
# 4      13.00317779.996902  NL01AB6068_04102021
# ...                   ...                  ...
# 16398  18.50342273.927742   NL01N3539_12102021
# 16399  18.49982673.946236   NL01N3539_12102021
# 16400  18.49779173.961311   NL01N3539_12102021
# 16401  18.49779173.961311   NL01N3539_12102021
# 16402  18.49779173.961311   NL01N3539_12102021
#
# [16403 rows x 6 columns]

# %%
dfframe_format12 = dfframe_format12[['Trip_id','Lat,Lngt','Latitude','Longitude','GPS_dt_tm']]

# %%
dfframe_format12.Trip_id.value_counts().sum()
# Out:
# 16403

# %%
dfframe_format12.isnull().sum()
# Out:
# Trip_id      0
# Lat,Lngt     0
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# dtype: int64

# %%
# concat - datasets

# %%
pdList = [dfframe_format1, dfframe_format2,dfframe_format3,dfframe_format4,dfframe_format5,dfframe_format6,dfframe_format7,dfframe_format8,dfframe_format9,dfframe_format10,dfframe_format11,dfframe_format12,dfframe_format13,dfframe_format14,dfframe_format16,dfframe_format17,dfframe_format18,dfframe_format19]  # List of your dataframes
master_data = pd.concat(pdList)

# %%
master_data.drop('Packet Time',axis = 1,inplace=True)

# %%
master_data.shape
# Out:
# (2663905, 5)

# %%
master_data
# Out:
#                    Trip_id             Lat,Lngt Latitude Longitude  \
# 0       NL01G7717_23102021    13.02534780.03511  13.0253   80.0351
# 1       NL01G7717_23102021   13.02536880.035034  13.0254    80.035
# 2       NL01G7717_23102021   13.02536880.035034  13.0254    80.035
# 3       NL01G7717_23102021   13.02534380.034996  13.0253    80.035
# 4       NL01G7717_23102021   13.02534380.034996  13.0253    80.035
# ...                    ...                  ...      ...       ...
# 181061  NL01Q6778_10082021    15.2959,76.912409  15.2959   76.9124
# 181062  NL01Q6778_10082021  15.267827,76.911796  15.2678   76.9118
# 181063  NL01Q6778_10082021  15.236758,76.908142  15.2368   76.9081
# 181064  NL01Q6778_10082021  15.200762,76.910693  15.2008   76.9107
# 181065  NL01Q6778_10082021  15.188828,76.911902  15.1888   76.9119
#
#                   GPS_dt_tm
# 0       2021-10-23 00:00:00
# 1       2021-10-23 00:05:00
# 2       2021-10-23 00:10:00
# 3       2021-10-23 00:15:00
# 4       2021-10-23 00:20:00
# ...                     ...
# 181061  2021-08-15 23:42:00
# 181062  2021-08-15 23:47:00
# 181063  2021-08-15 23:52:00
# 181064  2021-08-15 23:57:00
# 181065  2021-08-15 23:58:00
#
# [2663905 rows x 5 columns]

# %%
#pdList = []
#pdList.extend(value for name, value in locals().items() if name.startswith('dfframe_'))

# %%
#master_data = pd.DataFrame(pdList)

# %%
#master_data

# %%
## Data Consistency

# %%
master_data['GPS_dt_tm'] = pd.to_datetime(master_data['GPS_dt_tm'])

# %%
#master_data.iloc[np.where(master_data['GPS_dt_tm']=='2021-1--20 0-17 ')]

# %%
master_data['Time_diff'] = [x.iloc[-1] - x.iloc[0] for x in master_data['GPS_dt_tm'].rolling(2) if len(x)>0]

# %%
master_data.dtypes
# Out:
# Trip_id               object
# Lat,Lngt              object
# Latitude              object
# Longitude             object
# GPS_dt_tm     datetime64[ns]
# Time_diff    timedelta64[ns]
# dtype: object

# %%
diff_v_counts = master_data['Time_diff'].value_counts()

# %%
master_data.shape
# Out:
# (2663905, 6)

# %%
2665006 - 2663762
# Out:
# 1244

# %%
#d.to_excel("d.xlsx")

# %%
d_percent_count = master_data.Time_diff.value_counts(normalize=True).mul(100).round(4).astype(str) + '%'

# %%
d_percent_count
# Out:
# 0 days 00:05:00     59.6843%
# 0 days 00:02:00     14.1475%
# 0 days 00:00:00      8.6491%
# 0 days 00:01:00      8.1247%
# 0 days 00:06:00      4.5849%
#                       ...
# 0 days 00:13:48         0.0%
# 0 days 10:50:00         0.0%
# 11 days 06:06:00        0.0%
# 9 days 12:16:00         0.0%
# 0 days 02:48:31         0.0%
# Name: Time_diff, Length: 2809, dtype: object

# %%
master_data.isnull().sum()
# Out:
# Trip_id      0
# Lat,Lngt     0
# Latitude     0
# Longitude    0
# GPS_dt_tm    0
# Time_diff    0
# dtype: int64

# %%
master_data.Trip_id.value_counts().count()
# Out:
# 1551

# %%
master_data.Trip_id.nunique()
# Out:
# 1551

# %%
master_data.describe(include='O')
# Out:
#                           Trip_id            Lat,Lngt      Latitude  \
# count                     2663905             2663905  2.663905e+06
# unique                       1551             1162702  9.945210e+05
# top     HR46E0510_02.09.2021.xlsx  13.02395680.027519  1.302369e+01
# freq                        29350                1569  1.813000e+03
#
#            Longitude
# count   2.663905e+06
# unique  7.617330e+05
# top     8.283847e+01
# freq    4.246000e+03

# %%
master_data.Trip_id = master_data.Trip_id.str.replace('[.xls]', '')
master_data.Trip_id = master_data.Trip_id.str.replace('[.xlsx]', '')

# %%
trips_per_id=master_data[['Trip_id','Lat,Lngt']].drop_duplicates().groupby(['Trip_id']).count()

# %%
trips_per_id
# Out:
#                      Lat,Lngt
# Trip_id
# 7530NL01N_06102021        959
# 9562HR55T_16102021        754
# GJ06AX5553_03092021       751
# GJ06AX5749_09092021       182
# GJ06AX5749_13092021       986
# ...                       ...
# UP82T5514_14092021        322
# UP82T6226_28082021        843
# UP82T6227_04092021        822
# UP82T6227_23082021        205
# UP82T6229_10082021        681
#
# [1538 rows x 1 columns]

# %%
drv_hr = master_data.groupby(['Trip_id', 'Time_diff', 'Lat,Lngt']).count()

# %%
drv_hr
# Out:
#                                                         Latitude  Longitude  \
# Trip_id            Time_diff       Lat,Lngt
# 7530NL01N_06102021 0 days 00:00:00 28.416878,76.866773         1          1
#                    0 days 00:05:00 12.508967,78.225022         1          1
#                                    12.526561,78.207787         1          1
#                                    12.533799,78.247449         1          1
#                                    12.537781,78.3792           1          1
# ...                                                          ...        ...
# UP82T6229_10082021 0 days 00:44:00 18.60150575.118622          1          1
#                    0 days 01:20:00 17.63627275.708748          1          1
#                    0 days 01:21:00 15.3972676.307198           1          1
#                    0 days 05:29:00 20.55426273.058304          1          1
#                    0 days 08:01:00 18.95710474.814651          1          1
#
#                                                         GPS_dt_tm
# Trip_id            Time_diff       Lat,Lngt
# 7530NL01N_06102021 0 days 00:00:00 28.416878,76.866773          1
#                    0 days 00:05:00 12.508967,78.225022          1
#                                    12.526561,78.207787          1
#                                    12.533799,78.247449          1
#                                    12.537781,78.3792            1
# ...                                                           ...
# UP82T6229_10082021 0 days 00:44:00 18.60150575.118622           1
#                    0 days 01:20:00 17.63627275.708748           1
#                    0 days 01:21:00 15.3972676.307198            1
#                    0 days 05:29:00 20.55426273.058304           1
#                    0 days 08:01:00 18.95710474.814651           1
#
# [1226346 rows x 3 columns]

# %% [markdown]
# # Master_City_Master/ Master_city_Working

# %% [markdown]
# # Single City - Single/Multiple dealer

# %%
master_city_m = pd.read_excel("D:\\Sales Logistic Project\\Master_Single_City.xltm",sheet_name='Master')

# %%
master_city_w = pd.read_excel("D:\\Sales Logistic Project\\Master_Single_City.xltm",sheet_name='working')

# %%
master_city_m = master_city_m[['UNIQUE ID','City code','Dealer code',2,3,4]]

# %%
master_city_m.columns = ['Trip_id_m','City_Code','Dealer_code1','Dealer_code2','Dealer_code3','Dealer_code4']

# %%
master_city_m
# Out:
#                     Trip_id_m City_Code Dealer_code1 Dealer_code2  \
# 0       KA01AH0061_13.07.2021       W10        W1219          NaN
# 1       KA01AH0061_14.08.2021       W10        W1201        W1A00
# 2       GJ01ET5554_31.07.2021       W10        W1210          NaN
# 3       GJ01ET5595_11.09.2021       W10        W1210        W1A00
# 4       GJ01ET5595_30.07.2021       W26        W2207          NaN
# ...                       ...       ...          ...          ...
# 11962    UP82T6226_15.07.2021       S83        S8A08          NaN
# 11963    UP82T6227_14.07.2021       S80        S8213          NaN
# 11964    UP82T6227_23.08.2021       SEL        S5226          NaN
# 11965    UP82T6229_15.09.2021       S82        S8212          NaN
# 11966    UP82T6230_05.07.2021       S81        S8220          NaN
#
#       Dealer_code3 Dealer_code4
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3            W1A02          NaN
# 4              NaN          NaN
# ...            ...          ...
# 11962          NaN          NaN
# 11963          NaN          NaN
# 11964          NaN          NaN
# 11965          NaN          NaN
# 11966          NaN          NaN
#
# [11967 rows x 6 columns]

# %%
master_city_m.Trip_id = master_city_m.Trip_id_m.str.replace('[.xls]', '')
master_city_m.Trip_id = master_city_m.Trip_id_m.str.replace('[.xlsx]', '')
# Out:
# <ipython-input-200-bcc9feea0412>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   master_city_m.Trip_id = master_city_m.Trip_id_m.str.replace('[.xls]', '')

# %%
master_city_m
# Out:
#                     Trip_id_m City_Code Dealer_code1 Dealer_code2  \
# 0       KA01AH0061_13.07.2021       W10        W1219          NaN
# 1       KA01AH0061_14.08.2021       W10        W1201        W1A00
# 2       GJ01ET5554_31.07.2021       W10        W1210          NaN
# 3       GJ01ET5595_11.09.2021       W10        W1210        W1A00
# 4       GJ01ET5595_30.07.2021       W26        W2207          NaN
# ...                       ...       ...          ...          ...
# 11962    UP82T6226_15.07.2021       S83        S8A08          NaN
# 11963    UP82T6227_14.07.2021       S80        S8213          NaN
# 11964    UP82T6227_23.08.2021       SEL        S5226          NaN
# 11965    UP82T6229_15.09.2021       S82        S8212          NaN
# 11966    UP82T6230_05.07.2021       S81        S8220          NaN
#
#       Dealer_code3 Dealer_code4
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3            W1A02          NaN
# 4              NaN          NaN
# ...            ...          ...
# 11962          NaN          NaN
# 11963          NaN          NaN
# 11964          NaN          NaN
# 11965          NaN          NaN
# 11966          NaN          NaN
#
# [11967 rows x 6 columns]

# %%
master_city_w
# Out:
#                      VIN  Truck Plate Sold-to party Dealer code Gateout Date  \
# 0      MALPC815MMM604565   KA01AH0061    A10AGW1201       W1201   14.08.2021
# 1      MALPC813MMM604509   KA01AH0061    A10AGW1201       W1201   14.08.2021
# 2      MALPC812TMM222806   KA01AH0061    A10AGW1A00       W1A00   14.08.2021
# 3      MALPC813MMM804163   KA01AH0061    A10AGW1201       W1201   14.08.2021
# 4      MALPC812TMM222814   KA01AH0061    A10AGW1A00       W1A00   14.08.2021
# ...                  ...          ...           ...         ...          ...
# 74553  MALFC81DLMM254949    UP82T6229    A10AGS8212       S8212   15.09.2021
# 74554  MALB351CLMM237510    UP82T6229    A10AGS8212       S8212   15.09.2021
# 74555  MALB251CLMM237472    UP82T6229    A10AGS8212       S8212   15.09.2021
# 74556  MALBH512TMM097977    UP82T6229    A10AGS8212       S8212   15.09.2021
# 74557  MALB351CLMM213223    UP82T6230    A10AGS8220       S8220   05.07.2021
#
#       City  City Name POD Arrival Date    R/O Bill type Truck Code  Load Qty  \
# 0      W10     Mumbai       19.08.2021  W1101      ZVF2      U0023         5
# 1      W10     Mumbai       19.08.2021  W1101      ZVF2      U0023         5
# 2      W10     Mumbai       19.08.2021  W1101      ZVF2      U0023         5
# 3      W10     Mumbai       19.08.2021  W1101      ZVF2      U0023         5
# 4      W10     Mumbai       19.08.2021  W1101      ZVF2      U0023         5
# ...    ...        ...              ...    ...       ...        ...       ...
# 74553  S82  Mangalore       17.09.2021  S1104      ZVF2      F7736         8
# 74554  S82  Mangalore       17.09.2021  S1104      ZVF2      F7736         8
# 74555  S82  Mangalore       17.09.2021  S1104      ZVF2      F7736         8
# 74556  S82  Mangalore       17.09.2021  S1104      ZVF2      F7736         8
# 74557  S81      Hubli       08.07.2021  S1104      ZVF2      F7075         8
#
#       Sub Vendor               UNIQUE ID City.1 Dealer code.1
# 0          TP004   KA01AH0061_14.08.2021    W10         W1201
# 1          TP004   KA01AH0061_14.08.2021    W10         W1201
# 2          TP004   KA01AH0061_14.08.2021    W10         W1A00
# 3          TP004   KA01AH0061_14.08.2021    W10         W1201
# 4          TP004   KA01AH0061_14.08.2021    W10         W1A00
# ...          ...                     ...    ...           ...
# 74553      TP093    UP82T6229_15.09.2021    S82         S8212
# 74554      TP093    UP82T6229_15.09.2021    S82         S8212
# 74555      TP093    UP82T6229_15.09.2021    S82         S8212
# 74556      TP093    UP82T6229_15.09.2021    S82         S8212
# 74557      TP093    UP82T6230_05.07.2021    S81         S8220
#
# [74558 rows x 16 columns]

# %%
master_data_city_m_merge = pd.merge(master_data, master_city_m['Trip_id_m'], left_on='Trip_id', right_on = 'Trip_id_m', how = 'outer',indicator=True)
master_data_city_m_merge.shape
# Out:
# (2675872, 8)

# %%
master_data_city_m_merge
# Out:
#                     Trip_id            Lat,Lngt Latitude Longitude  \
# 0        NL01G7717_23102021   13.02534780.03511  13.0253   80.0351
# 1        NL01G7717_23102021  13.02536880.035034  13.0254    80.035
# 2        NL01G7717_23102021  13.02536880.035034  13.0254    80.035
# 3        NL01G7717_23102021  13.02534380.034996  13.0253    80.035
# 4        NL01G7717_23102021  13.02534380.034996  13.0253    80.035
# ...                     ...                 ...      ...       ...
# 2675867                 NaN                 NaN      NaN       NaN
# 2675868                 NaN                 NaN      NaN       NaN
# 2675869                 NaN                 NaN      NaN       NaN
# 2675870                 NaN                 NaN      NaN       NaN
# 2675871                 NaN                 NaN      NaN       NaN
#
#                   GPS_dt_tm       Time_diff             Trip_id_m      _merge
# 0       2021-10-23 00:00:00 0 days 00:00:00                   NaN   left_only
# 1       2021-10-23 00:05:00 0 days 00:05:00                   NaN   left_only
# 2       2021-10-23 00:10:00 0 days 00:05:00                   NaN   left_only
# 3       2021-10-23 00:15:00 0 days 00:05:00                   NaN   left_only
# 4       2021-10-23 00:20:00 0 days 00:05:00                   NaN   left_only
# ...                     ...             ...                   ...         ...
# 2675867                 NaT             NaT  UP82T6226_15.07.2021  right_only
# 2675868                 NaT             NaT  UP82T6227_14.07.2021  right_only
# 2675869                 NaT             NaT  UP82T6227_23.08.2021  right_only
# 2675870                 NaT             NaT  UP82T6229_15.09.2021  right_only
# 2675871                 NaT             NaT  UP82T6230_05.07.2021  right_only
#
# [2675872 rows x 8 columns]

# %%
## Multiple City

# %%
mult_master_city = pd.read_excel("D:\\Sales Logistic Project\\Multiple_City.xltm",sheet_name='Multi city')

# %%
mult_master_city
# Out:
#       asdfas              UNIQUE ID Dealer code      2      3    4    5    6  \
# 0          0      BYROAD_14.09.2021       S1215    NaN    NaN  NaN  NaN  NaN
# 1          0  GJ01ET5554_25.09.2021       W2207  W2240    NaN  NaN  NaN  NaN
# 2          0  GJ01ET5602_02.08.2021       W1210  W2260    NaN  NaN  NaN  NaN
# 3          0  GJ01ET5674_30.09.2021       N4241  N4A08    NaN  NaN  NaN  NaN
# 4          0  GJ01ET5682_11.08.2021       S7228  S7234    NaN  NaN  NaN  NaN
# ...      ...                    ...         ...    ...    ...  ...  ...  ...
# 7563       0   UP82T6227_11.07.2021       S5217  S5A06    NaN  NaN  NaN  NaN
# 7564       0   UP82T6227_20.07.2021       N3238  N3A12    NaN  NaN  NaN  NaN
# 7565       0   UP82T6228_28.07.2021       W3246  W3256    NaN  NaN  NaN  NaN
# 7566       0   UP82T6229_10.08.2021       W3201  W3252  W3256  NaN  NaN  NaN
# 7567       0   UP82T6230_09.09.2021       S4215  S4222    NaN  NaN  NaN  NaN
#
#         7    8   9
# 0     NaN  NaN NaN
# 1     NaN  NaN NaN
# 2     NaN  NaN NaN
# 3     NaN  NaN NaN
# 4     NaN  NaN NaN
# ...   ...  ...  ..
# 7563  NaN  NaN NaN
# 7564  NaN  NaN NaN
# 7565  NaN  NaN NaN
# 7566  NaN  NaN NaN
# 7567  NaN  NaN NaN
#
# [7568 rows x 11 columns]

# %%
mult_master_city = mult_master_city[['UNIQUE ID','Dealer code',2,3,4,5]]

# %%
mult_master_city.columns = ['Trip_id_m','Dealer_Code1','Dealer_code2','Dealer_code3','Dealer_code4','Dealer_code5']

# %%
mult_master_city
# Out:
#                   Trip_id_m Dealer_Code1 Dealer_code2 Dealer_code3  \
# 0         BYROAD_14.09.2021        S1215          NaN          NaN
# 1     GJ01ET5554_25.09.2021        W2207        W2240          NaN
# 2     GJ01ET5602_02.08.2021        W1210        W2260          NaN
# 3     GJ01ET5674_30.09.2021        N4241        N4A08          NaN
# 4     GJ01ET5682_11.08.2021        S7228        S7234          NaN
# ...                     ...          ...          ...          ...
# 7563   UP82T6227_11.07.2021        S5217        S5A06          NaN
# 7564   UP82T6227_20.07.2021        N3238        N3A12          NaN
# 7565   UP82T6228_28.07.2021        W3246        W3256          NaN
# 7566   UP82T6229_10.08.2021        W3201        W3252        W3256
# 7567   UP82T6230_09.09.2021        S4215        S4222          NaN
#
#      Dealer_code4 Dealer_code5
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 7563          NaN          NaN
# 7564          NaN          NaN
# 7565          NaN          NaN
# 7566          NaN          NaN
# 7567          NaN          NaN
#
# [7568 rows x 6 columns]

# %%
mult_master_city.Trip_id_m = mult_master_city.Trip_id_m.str.replace('[.]', '')
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
mult_master_city.Trip_id_m
# Out:
# 0           BYROAD_14092021
# 1       GJ01ET5554_25092021
# 2       GJ01ET5602_02082021
# 3       GJ01ET5674_30092021
# 4       GJ01ET5682_11082021
#                ...
# 7563     UP82T6227_11072021
# 7564     UP82T6227_20072021
# 7565     UP82T6228_28072021
# 7566     UP82T6229_10082021
# 7567     UP82T6230_09092021
# Name: Trip_id_m, Length: 7568, dtype: object

# %%
mult_master_city
# Out:
#                 Trip_id_m Dealer_Code1 Dealer_code2 Dealer_code3 Dealer_code4  \
# 0         BYROAD_14092021        S1215          NaN          NaN          NaN
# 1     GJ01ET5554_25092021        W2207        W2240          NaN          NaN
# 2     GJ01ET5602_02082021        W1210        W2260          NaN          NaN
# 3     GJ01ET5674_30092021        N4241        N4A08          NaN          NaN
# 4     GJ01ET5682_11082021        S7228        S7234          NaN          NaN
# ...                   ...          ...          ...          ...          ...
# 7563   UP82T6227_11072021        S5217        S5A06          NaN          NaN
# 7564   UP82T6227_20072021        N3238        N3A12          NaN          NaN
# 7565   UP82T6228_28072021        W3246        W3256          NaN          NaN
# 7566   UP82T6229_10082021        W3201        W3252        W3256          NaN
# 7567   UP82T6230_09092021        S4215        S4222          NaN          NaN
#
#      Dealer_code5
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 7563          NaN
# 7564          NaN
# 7565          NaN
# 7566          NaN
# 7567          NaN
#
# [7568 rows x 6 columns]
